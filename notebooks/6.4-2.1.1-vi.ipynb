# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

import seaborn as sns

import sys
from os import getcwd, path
sys.path.append(path.dirname(getcwd()))

from infino import cibersort_data, plot_dataset, plot_settings, stansummary_data, model_check

import re
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from infino import CELL_TYPES, ROLLUPS, CIBERSORT_CELL_TYPES, CIBERSORT_ROLLUPS, CIBERSORT_DATA_DIR, STAN_PARAMETER_NAMES

# %%
STAN_DATA_DIR = '/Users/eliza/data/modelcache_new/experiments/20171207_6.4otherbucket_vi'

# %%
STAN_SUMMARY = pd.read_csv(path.join(STAN_DATA_DIR, "2.1.1_vi_stansummary.csv"), comment='#')

# %%
metrics = ["MCSE", "N_Eff", 'StdDev']
parameters = ["other_log_contribution_per_gene", "unknown_prop", "sample2_x"]

# %%
STAN_SUMMARY
# Out:
#                  name       Mean          MCSE        StdDev         5%  \
# 0                lp__   0.000000  0.000000e+00  0.000000e+00   0.000000
# 1        Omega_L[1,1]   1.000000  1.369230e-16  4.332030e-15   1.000000
# 2        Omega_L[1,2]   0.000000  0.000000e+00  0.000000e+00   0.000000
# 3        Omega_L[1,3]   0.000000  0.000000e+00  0.000000e+00   0.000000
# 4        Omega_L[1,4]   0.000000  0.000000e+00  0.000000e+00   0.000000
# 5        Omega_L[1,5]   0.000000  0.000000e+00  0.000000e+00   0.000000
# 6        Omega_L[1,6]   0.000000  0.000000e+00  0.000000e+00   0.000000
# 7        Omega_L[1,7]   0.000000  0.000000e+00  0.000000e+00   0.000000
# 8        Omega_L[1,8]   0.000000  0.000000e+00  0.000000e+00   0.000000
# 9        Omega_L[1,9]   0.000000  0.000000e+00  0.000000e+00   0.000000
# 10      Omega_L[1,10]   0.000000  0.000000e+00  0.000000e+00   0.000000
# 11      Omega_L[1,11]   0.000000  0.000000e+00  0.000000e+00   0.000000
# ...

# %%
test_param = "Omega_L[1,1]"
